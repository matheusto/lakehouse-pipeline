# %%
# %pip install dbt-databricks

# %%
# %sh dbt --version

# %%
# %sh cd /Workspace/Users/matheus.teodoro@solutis.com.br/lakehouse-pipeline/dbt_gold && dbt debug

# %%
# %sh cd /Workspace/Users/matheus.teodoro@solutis.com.br/lakehouse-pipeline/dbt_gold && dbt run

# %%
# %sh cd /Workspace/Users/matheus.teodoro@solutis.com.br/lakehouse-pipeline/dbt_gold && dbt run --select mart_by_state
